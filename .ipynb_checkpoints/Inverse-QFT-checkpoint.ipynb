# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def iqft_matrix_render1(sv_entries_count):
    import numpy as np 
    import cmath
    from IPython.display import display, Markdown
    print("QFT matrix for qubit statevctor of with ", sv_entries_count, " is:\n")
    
    N   = str(sv_entries_count)
    text = r"$QFT^{{\dagger}} = \frac{{1}}{{\sqrt{{{N}}}}} \begin{{bmatrix}}".format(N=N)
    
    ele = ''
    dim = sv_entries_count
    
    # Code for rendering loop 
    for i in range(dim): # row indexer = Table
        for j in range(dim): # column indexer
            exponent = -1 * i * j 
            if exponent == 0:
                ele = '1'
            elif exponent == 1:
                ele = '\omega'
            else:
                ele = '\omega^{'+str(exponent)+'}'
                
            if j == dim-1:
                text = text + r' ' + ele + r' \\'
            else:        
                text = text + r' ' + ele + r' &'
     # end of for   
    text = text + r' \end{bmatrix}$'
    display(Markdown(text))
    
    return text
    

def iqft_matrix_render2(sv_entries_count):
    import numpy as np 
    import cmath
    from IPython.display import display, Markdown
    print("QFT matrix for qubit statevctor of with ", sv_entries_count, " is:\n")
    
    N   = str(sv_entries_count)
    text = r"$QFT^{{\dagger}} = \frac{{1}}{{\sqrt{{{N}}}}} \begin{{bmatrix}}".format(N=N)
    
    ele = ''
    dim = sv_entries_count
    
    # Code for rendering loop 
    for i in range(dim): # row indexer = Table
        for j in range(dim): # column indexer
            exponent = i * j 
            if exponent == 0:
                ele = '1'
            elif exponent == 1:
                ele = '\omega^{'+str((dim-1)**2)+'}'
            else:
                ele = '\omega^{'+str((dim-1)**2-exponent)+'}'
                
            if j == dim-1:
                text = text + r' ' + ele + r' \\'
            else:        
                text = text + r' ' + ele + r' &'
     # end of for   
    text = text + r' \end{bmatrix}$'
    display(Markdown(text))   
    
    return text

# %%
# Size of state vector 
# QFT does not distinguish if the state (vector) is a two-level system (qubit)
# or a combination of multi-level state qutrits 

# sv size is power of 2 but could be any value as well e.g. for sv size 3 means its a qutrit a 3 level system 
for i in range(3):
    sv_size = 2**i
    iqft_matrix_render1(sv_size)
# Out:
# QFT matrix for qubit statevctor of with  1  is:
# $QFT^{\dagger} = \frac{1}{\sqrt{1}} \begin{bmatrix} 1 \\ \end{bmatrix}$
# QFT matrix for qubit statevctor of with  2  is:
# $QFT^{\dagger} = \frac{1}{\sqrt{2}} \begin{bmatrix} 1 & 1 \\ 1 & \omega^{-1} \\ \end{bmatrix}$
# QFT matrix for qubit statevctor of with  4  is:
# $QFT^{\dagger} = \frac{1}{\sqrt{4}} \begin{bmatrix} 1 & 1 & 1 & 1 \\ 1 & \omega^{-1} & \omega^{-2} & \omega^{-3} \\ 1 & \omega^{-2} & \omega^{-4} & \omega^{-6} \\ 1 & \omega^{-3} & \omega^{-6} & \omega^{-9} \\ \end{bmatrix}$

# %%
# Size of state vector 
# QFT does not distinguish if the state (vector) is a two-level system (qubit)
# or a combination of multi-level state qutrits 

# sv size is power of 2 but could be any value as well e.g. for sv size 3 means its a qutrit a 3 level system 
for i in range(3):
    sv_size = 2**i
    iqft_matrix_render2(sv_size)
# Out:
# QFT matrix for qubit statevctor of with  1  is:
# $QFT^{\dagger} = \frac{1}{\sqrt{1}} \begin{bmatrix} 1 \\ \end{bmatrix}$
# QFT matrix for qubit statevctor of with  2  is:
# $QFT^{\dagger} = \frac{1}{\sqrt{2}} \begin{bmatrix} 1 & 1 \\ 1 & \omega^{1} \\ \end{bmatrix}$
# QFT matrix for qubit statevctor of with  4  is:
# $QFT^{\dagger} = \frac{1}{\sqrt{4}} \begin{bmatrix} 1 & 1 & 1 & 1 \\ 1 & \omega^{9} & \omega^{7} & \omega^{6} \\ 1 & \omega^{7} & \omega^{5} & \omega^{3} \\ 1 & \omega^{6} & \omega^{3} & \omega^{0} \\ \end{bmatrix}$

# %%
t = iqft_matrix_render2(4)
# Out:
# QFT matrix for qubit statevctor of with  4  is:
# $QFT^{\dagger} = \frac{1}{\sqrt{4}} \begin{bmatrix} 1 & 1 & 1 & 1 \\ 1 & \omega^{9} & \omega^{7} & \omega^{6} \\ 1 & \omega^{7} & \omega^{5} & \omega^{3} \\ 1 & \omega^{6} & \omega^{3} & \omega^{0} \\ \end{bmatrix}$

# %%
def iqft_matrix_compute(sv_entries_count, precision=-1):
    import numpy as np 
    import cmath
    dim = sv_entries_count

    #qft_matrix = [complex(0.0,0.0)] * sv_entries_count*sv_entries_count
    
    qft_matrix = np.zeros((sv_entries_count,sv_entries_count), dtype=complex)


    for i in range(dim): 
        for j in range(dim): 
            qft_matrix[i][j] = 1.0/cmath.sqrt(sv_entries_count) * cmath.exp(-2*cmath.pi*1j*i*j / sv_entries_count)       
    
    if precision != -1:
        qft_matrix = np.around(qft_matrix,precision)
        
    return qft_matrix

# %%
import numpy as np 
import math, cmath

psi_ket = np.array([[1/math.sqrt(4)],[1/math.sqrt(4)],[1/math.sqrt(4)],[1/math.sqrt(4)]])

psi_ket = np.array([[0],[1/math.sqrt(2)],[-1/math.sqrt(2)],[0]])

psi_ket = np.array([[0],[1/math.sqrt(2)],[1/math.sqrt(2)],[0]])

psi_ket = np.array([[0],[0],[0],[1]])


from qiskit.visualization import array_to_latex
     
M_QFT = array_to_latex(iqft_matrix_compute(sv_size), source=True)
SV = array_to_latex(psi_ket, source=True)
QFT_SV = array_to_latex(np.matmul(iqft_matrix_compute(sv_size), psi_ket), source=True)


from IPython.display import display, Markdown

final_text =  M_QFT + SV + QFT_SV

display(Markdown(final_text))
# Out:
# \begin{bmatrix}
# \tfrac{1}{2} & \tfrac{1}{2} & \tfrac{1}{2} & \tfrac{1}{2}  \\
#  \tfrac{1}{2} & -\tfrac{1}{2}i & -\tfrac{1}{2} & \tfrac{1}{2}i  \\
#  \tfrac{1}{2} & -\tfrac{1}{2} & \tfrac{1}{2} & -\tfrac{1}{2}  \\
#  \tfrac{1}{2} & \tfrac{1}{2}i & -\tfrac{1}{2} & -\tfrac{1}{2}i  \\
#  \end{bmatrix}
#
#
# \begin{bmatrix}
# 0  \\
#  0  \\
#  0  \\
#  1  \\
#  \end{bmatrix}
#
#
# \begin{bmatrix}
# \tfrac{1}{2}  \\
#  \tfrac{1}{2}i  \\
#  -\tfrac{1}{2}  \\
#  -\tfrac{1}{2}i  \\
#  \end{bmatrix}
